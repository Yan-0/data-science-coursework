# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("hotel_bookings.csv")

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0     2.0  ...    No Deposit
# 1                        0                     0     2.0  ...    No Deposit
# 2                        0                     1     1.0  ...    No Deposit
# 3                        0                     1     1.0  ...    No Deposit
# 4                        0                     2     2.0  ...    No Deposit
#
#    agent company days_in_waiting_list customer_type   adr  \
# 0    NaN     NaN                    0     Transient   0.0
# 1    NaN     NaN                    0     Transient   0.0
# 2    NaN     NaN                    0     Transient  75.0
# 3  304.0     NaN                    0     Transient  75.0
# 4  240.0     NaN                    0     Transient  98.0
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# 0                            0                          0           Check-Out
# 1                            0                          0           Check-Out
# 2                            0                          0           Check-Out
# 3                            0                          0           Check-Out
# 4                            0                          1           Check-Out
#
#   reservation_status_date
# 0              01/07/2015
# 1              01/07/2015
# 2              02/07/2015
# 3              02/07/2015
# 4              03/07/2015
#
# [5 rows x 32 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119389 non-null  float64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
#  12  meal                            119390 non-null  object
#  13  country                         118883 non-null  object
#  14  market_segment                  119388 non-null  object
#  15  distribution_channel            119389 non-null  object
#  16  is_repeated_guest               119390 non-null  int64
#  17  previous_cancellations          119390 non-null  int64
#  18  previous_bookings_not_canceled  119390 non-null  int64
#  19  reserved_room_type              119389 non-null  object
#  20  assigned_room_type              119389 non-null  object
#  21  booking_changes                 119390 non-null  int64
#  22  deposit_type                    119369 non-null  object
#  23  agent                           103050 non-null  float64
#  24  company                         6797 non-null    float64
#  25  days_in_waiting_list            119390 non-null  int64
#  26  customer_type                   119359 non-null  object
#  27  adr                             119390 non-null  float64
#  28  required_car_parking_spaces     119390 non-null  int64
#  29  total_of_special_requests       119390 non-null  int64
#  30  reservation_status              119389 non-null  object
#  31  reservation_status_date         119390 non-null  object
# dtypes: float64(5), int64(15), object(12)
# memory usage: 29.1+ MB

# %%
df.isna().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 1
# children                               4
# babies                                 0
# meal                                   0
# country                              507
# market_segment                         2
# distribution_channel                   1
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     1
# assigned_room_type                     1
# booking_changes                        0
# deposit_type                          21
# agent                              16340
# company                           112593
# days_in_waiting_list                   0
# customer_type                         31
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# reservation_status                     1
# reservation_status_date                0
# dtype: int64

# %%
df.drop(columns=['company'], inplace=True)

# %%
df.isna().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                1
# children                              4
# babies                                0
# meal                                  0
# country                             507
# market_segment                        2
# distribution_channel                  1
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    1
# assigned_room_type                    1
# booking_changes                       0
# deposit_type                         21
# agent                             16340
# days_in_waiting_list                  0
# customer_type                        31
# adr                                   0
# required_car_parking_spaces           0
# total_of_special_requests             0
# reservation_status                    1
# reservation_status_date               0
# dtype: int64

# %% [markdown]
# ##### Filling missing values

# %%
df['children'].fillna(df['children'].median(), inplace=True)
df['adults'].fillna(df['adults'].median(), inplace=True)
df['country'].fillna(df['country'].mode()[0],inplace=True)
df['market_segment'].fillna(df['market_segment'].mode()[0],inplace=True)
df['distribution_channel'].fillna(df['distribution_channel'].mode()[0],inplace=True)
df['reserved_room_type'].fillna(df['reserved_room_type'].mode()[0],inplace=True)
df['assigned_room_type'].fillna(df['assigned_room_type'].mode()[0],inplace=True)
df['deposit_type'].fillna(df['deposit_type'].mode()[0],inplace=True)
df['agent'].fillna(df['agent'].median(), inplace=True)
df['customer_type'].fillna(df['customer_type'].mode()[0],inplace=True)
df['reservation_status'].fillna(df['reservation_status'].mode()[0],inplace=True)

# %%
df.isna().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# required_car_parking_spaces       0
# total_of_special_requests         0
# reservation_status                0
# reservation_status_date           0
# dtype: int64

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# 119388                         31                        2
# 119389                         29                        2
#
#         stays_in_week_nights  adults  ...  booking_changes  deposit_type  \
# 119385                     5     2.0  ...                0    No Deposit
# 119386                     5     3.0  ...                0    No Deposit
# 119387                     5     2.0  ...                0    No Deposit
# 119388                     5     2.0  ...                0    No Deposit
# 119389                     7     2.0  ...                0    No Deposit
#
#         agent days_in_waiting_list customer_type     adr  \
# 119385  394.0                    0     Transient   96.14
# 119386    9.0                    0     Transient  225.43
# 119387    9.0                    0     Transient  157.71
# 119388   89.0                    0     Transient  104.40
# 119389    9.0                    0     Transient  151.20
#
#         required_car_parking_spaces  total_of_special_requests  \
# 119385                            0                          0
# 119386                            0                          2
# 119387                            0                          4
# 119388                            0                          0
# 119389                            0                          2
#
#         reservation_status reservation_status_date
# 119385           Check-Out              06/09/2017
# 119386           Check-Out              07/09/2017
# 119387           Check-Out              07/09/2017
# 119388           Check-Out              07/09/2017
# 119389           Check-Out              07/09/2017
#
# [5 rows x 31 columns]

# %%
#Checking duplicate values
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 119385    False
# 119386    False
# 119387    False
# 119388    False
# 119389    False
# Length: 119390, dtype: bool

# %%
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format="%d/%m/%Y")

# %%
df['reservation_status_date']
# Out:
# 0        2015-07-01
# 1        2015-07-01
# 2        2015-07-02
# 3        2015-07-02
# 4        2015-07-03
#             ...
# 119385   2017-09-06
# 119386   2017-09-07
# 119387   2017-09-07
# 119388   2017-09-07
# 119389   2017-09-07
# Name: reservation_status_date, Length: 119390, dtype: datetime64[ns]

# %% [markdown]
# ##### Descriptive Statistics

# %%
#Calculating summary statistics (mean, median, mode, standard deviation, etc.)

num_cols = [
    'lead_time', 'stays_in_weekend_nights', 'stays_in_week_nights', 
    'adults', 'children', 'babies', 'previous_cancellations', 
    'previous_bookings_not_canceled', 'days_in_waiting_list', 'adr', 
    'required_car_parking_spaces', 'total_of_special_requests'
]
summary_stats = df[num_cols].describe()
summary_stats
# Out:
#            lead_time  stays_in_weekend_nights  stays_in_week_nights  \
# count  119390.000000            119390.000000         119390.000000
# mean      104.011416                 0.927599              2.500302
# std       106.863097                 0.998613              1.908286
# min         0.000000                 0.000000              0.000000
# 25%        18.000000                 0.000000              1.000000
# 50%        69.000000                 1.000000              2.000000
# 75%       160.000000                 2.000000              3.000000
# max       737.000000                19.000000             50.000000
#
#               adults       children         babies  previous_cancellations  \
# count  119390.000000  119390.000000  119390.000000           119390.000000
# mean        1.856403       0.103886       0.007949                0.087118
# std         0.579261       0.398555       0.097436                0.844336
# min         0.000000       0.000000       0.000000                0.000000
# 25%         2.000000       0.000000       0.000000                0.000000
# 50%         2.000000       0.000000       0.000000                0.000000
# 75%         2.000000       0.000000       0.000000                0.000000
# max        55.000000      10.000000      10.000000               26.000000
#
#        previous_bookings_not_canceled  days_in_waiting_list            adr  \
# count                   119390.000000         119390.000000  119390.000000
# mean                         0.137097              2.321149     101.831122
# std                          1.497437             17.594721      50.535790
# min                          0.000000              0.000000      -6.380000
# 25%                          0.000000              0.000000      69.290000
# 50%                          0.000000              0.000000      94.575000
# 75%                          0.000000              0.000000     126.000000
# max                         72.000000            391.000000    5400.000000
#
#        required_car_parking_spaces  total_of_special_requests
# count                119390.000000              119390.000000
# mean                      0.062518                   0.571363
# std                       0.245291                   0.792798
# min                       0.000000                   0.000000
# 25%                       0.000000                   0.000000
# 50%                       0.000000                   0.000000
# 75%                       0.000000                   1.000000
# max                       8.000000                   5.000000

# %%
# Calculating mode for each numerical column

mode_stats = df[num_cols].mode().iloc[0]
mode_stats
# Out:
# lead_time                          0.0
# stays_in_weekend_nights            0.0
# stays_in_week_nights               2.0
# adults                             2.0
# children                           0.0
# babies                             0.0
# previous_cancellations             0.0
# previous_bookings_not_canceled     0.0
# days_in_waiting_list               0.0
# adr                               62.0
# required_car_parking_spaces        0.0
# total_of_special_requests          0.0
# Name: 0, dtype: float64

# %%
## Display value counts and frequencies for categorical columns

cat_cols = [
    'hotel', 'country', 'market_segment', 'distribution_channel',
    'is_repeated_guest', 'reserved_room_type', 'assigned_room_type',
    'deposit_type', 'agent', 'customer_type', 'reservation_status'
]

for column in cat_cols:
    print(f"\nValue Counts for {column}:\n{df[column].value_counts()}\n")
# Out:
# Value Counts for hotel:
# hotel
# City Hotel      79330
# Resort Hotel    40060
# Name: count, dtype: int64
#
#
# Value Counts for country:
# country
# PRT    49078
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
#        ...
# DJI        1
# BWA        1
# HND        1
# VGB        1
# NAM        1
# Name: count, Length: 177, dtype: int64
#
#
# Value Counts for market_segment:
# market_segment
# Online TA        56479
# Offline TA/TO    24217
# Groups           19811
# Direct           12606
# Corporate         5295
# Complementary      743
# Aviation           237
# Undefined            2
# Name: count, dtype: int64
#
#
# Value Counts for distribution_channel:
# distribution_channel
# TA/TO        97870
# Direct       14645
# Corporate     6677
# GDS            193
# Undefined        5
# Name: count, dtype: int64
#
#
# Value Counts for is_repeated_guest:
# is_repeated_guest
# 0    115580
# 1      3810
# Name: count, dtype: int64
#
#
# Value Counts for reserved_room_type:
# reserved_room_type
# A    85995
# D    19200
# E     6535
# F     2897
# G     2094
# B     1118
# C      932
# H      601
# P       12
# L        6
# Name: count, dtype: int64
#
#
# Value Counts for assigned_room_type:
# assigned_room_type
# A    74054
# D    25322
# E     7805
# F     3751
# G     2553
# C     2375
# B     2163
# H      712
# I      363
# K      279
# P       12
# L        1
# Name: count, dtype: int64
#
#
# Value Counts for deposit_type:
# deposit_type
# No Deposit    104652
# Non Refund     14576
# Refundable       162
# Name: count, dtype: int64
#
#
# Value Counts for agent:
# agent
# 9.0      31961
# 14.0     19980
# 240.0    13922
# 1.0       7191
# 7.0       3539
#          ...
# 265.0        1
# 93.0         1
# 294.0        1
# 431.0        1
# 433.0        1
# Name: count, Length: 333, dtype: int64
#
#
# Value Counts for customer_type:
# customer_type
# Transient          89617
# Transient-Party    25120
# Contract            4076
# Group                577
# Name: count, dtype: int64
#
#
# Value Counts for reservation_status:
# reservation_status
# Check-Out    75166
# Canceled     43017
# No-Show       1207
# Name: count, dtype: int64

# %% [markdown]
# ##### Data Visualization

# %%
num_cols
# Out:
# ['lead_time',
#  'stays_in_weekend_nights',
#  'stays_in_week_nights',
#  'adults',
#  'children',
#  'babies',
#  'previous_cancellations',
#  'previous_bookings_not_canceled',
#  'days_in_waiting_list',
#  'adr',
#  'required_car_parking_spaces',
#  'total_of_special_requests']

# %%
#Histogram

plt.figure(figsize=(16, 12))
for i, col in enumerate(num_cols, 1):
    plt.subplot(3, 4, i)
    plt.hist(df[col], bins=20, edgecolor='black')
    plt.title(col)
plt.tight_layout()
plt.show()

# %%
# Plotting box plots for numerical columns

plt.figure(figsize=(12, 8))
plt.boxplot(df[num_cols])
plt.title('Box Plot')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
#Categorical columns
cat_cols
# Out:
# ['hotel',
#  'country',
#  'market_segment',
#  'distribution_channel',
#  'is_repeated_guest',
#  'reserved_room_type',
#  'assigned_room_type',
#  'deposit_type',
#  'agent',
#  'customer_type',
#  'reservation_status']

# %%
plt.figure(figsize=(18, 20))
for i, col in enumerate(cat_cols, 1):
    plt.subplot(4, 3, i)
    value_counts = df[col].value_counts()
    
    if len(value_counts) <= 10:  # Bar plot if fewer categories
        plt.bar(value_counts.index, value_counts.values)
        plt.xticks(rotation=45, ha='right')
        plt.ylabel('Count')
    else:  # Pie chart if many categories
        plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%', startangle=90)
        plt.ylabel('')  # Hide the y-label for pie charts
    
    plt.title(col)
    
plt.tight_layout(pad=3.0)
plt.show()

# %%
import seaborn as sns

# Plot scatter plots for relationships between numerical columns
# Set the figure size
plt.figure(figsize=(20, 15))

# Create the pairplot with 6 subplots per row and larger subplots
sns.pairplot(df[num_cols], corner=True, height=3, aspect=1)

# Adjust the spacing between subplots
plt.subplots_adjust(wspace=0.4, hspace=0.4)

# Show the plot
plt.show()
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Line plot for trends over time

plt.figure(figsize=(10, 6))
plt.plot(df['reservation_status_date'], df['arrival_date_year'], label='Arrival Year')
plt.plot(df['reservation_status_date'], df['arrival_date_week_number'], label='Arrival Week Number')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Trends Over Time')
plt.legend()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Correction Analysis

# %%
num_cols
# Out:
# ['lead_time',
#  'stays_in_weekend_nights',
#  'stays_in_week_nights',
#  'adults',
#  'children',
#  'babies',
#  'previous_cancellations',
#  'previous_bookings_not_canceled',
#  'days_in_waiting_list',
#  'adr',
#  'required_car_parking_spaces',
#  'total_of_special_requests']

# %%
# Calculate the correlation matrix
correlation_matrix = df[num_cols].corr()
correlation_matrix
# Out:
#                                 lead_time  stays_in_weekend_nights  \
# lead_time                        1.000000                 0.085671
# stays_in_weekend_nights          0.085671                 1.000000
# stays_in_week_nights             0.165799                 0.498969
# adults                           0.119519                 0.091871
# children                        -0.037613                 0.045794
# babies                          -0.020915                 0.018483
# previous_cancellations           0.086042                -0.012775
# previous_bookings_not_canceled  -0.073548                -0.042715
# days_in_waiting_list             0.170084                -0.054151
# adr                             -0.063077                 0.049342
# required_car_parking_spaces     -0.116451                -0.018554
# total_of_special_requests       -0.095712                 0.072671
#
#                                 stays_in_week_nights    adults  children  \
# lead_time                                   0.165799  0.119519 -0.037613
# stays_in_weekend_nights                     0.498969  0.091871  0.045794
# stays_in_week_nights                        1.000000  0.092976  0.044203
# adults                                      0.092976  1.000000  0.030440
# children                                    0.044203  0.030440  1.000000
# babies                                      0.020191  0.018146  0.024030
# previous_cancellations                     -0.013992 -0.006738 -0.024729
# previous_bookings_not_canceled             -0.048743 -0.107983 -0.021072
# days_in_waiting_list                       -0.002020 -0.008283 -0.033271
# adr                                         0.065237  0.230641  0.324853
# required_car_parking_spaces                -0.024859  0.014785  0.056255
# total_of_special_requests                   0.068192  0.122884  0.081736
#
#                                   babies  previous_cancellations  \
# lead_time                      -0.020915                0.086042
# stays_in_weekend_nights         0.018483               -0.012775
# stays_in_week_nights            0.020191               -0.013992
# adults                          0.018146               -0.006738
# children                        0.024030               -0.024729
# babies                          1.000000               -0.007501
# previous_cancellations         -0.007501                1.000000
# previous_bookings_not_canceled -0.006550                0.152728
# days_in_waiting_list           -0.010621                0.005929
# adr                             0.029186               -0.065646
# required_car_parking_spaces     0.037383               -0.018492
# total_of_special_requests       0.097889               -0.048384
#
#                                 previous_bookings_not_canceled  \
# lead_time                                            -0.073548
# stays_in_weekend_nights                              -0.042715
# stays_in_week_nights                                 -0.048743
# adults                                               -0.107983
# children                                             -0.021072
# babies                                               -0.006550
# previous_cancellations                                0.152728
# previous_bookings_not_canceled                        1.000000
# days_in_waiting_list                                 -0.009397
# adr                                                  -0.072144
# required_car_parking_spaces                           0.047653
# total_of_special_requests                             0.037824
#
#                                 days_in_waiting_list       adr  \
# lead_time                                   0.170084 -0.063077
# stays_in_weekend_nights                    -0.054151  0.049342
# stays_in_week_nights                       -0.002020  0.065237
# adults                                     -0.008283  0.230641
# children                                   -0.033271  0.324853
# babies                                     -0.010621  0.029186
# previous_cancellations                      0.005929 -0.065646
# previous_bookings_not_canceled             -0.009397 -0.072144
# days_in_waiting_list                        1.000000 -0.040756
# adr                                        -0.040756  1.000000
# required_car_parking_spaces                -0.030600  0.056628
# total_of_special_requests                  -0.082730  0.172185
#
#                                 required_car_parking_spaces  \
# lead_time                                         -0.116451
# stays_in_weekend_nights                           -0.018554
# stays_in_week_nights                              -0.024859
# adults                                             0.014785
# children                                           0.056255
# babies                                             0.037383
# previous_cancellations                            -0.018492
# previous_bookings_not_canceled                     0.047653
# days_in_waiting_list                              -0.030600
# adr                                                0.056628
# required_car_parking_spaces                        1.000000
# total_of_special_requests                          0.082626
#
#                                 total_of_special_requests
# lead_time                                       -0.095712
# stays_in_weekend_nights                          0.072671
# stays_in_week_nights                             0.068192
# adults                                           0.122884
# children                                         0.081736
# babies                                           0.097889
# previous_cancellations                          -0.048384
# previous_bookings_not_canceled                   0.037824
# days_in_waiting_list                            -0.082730
# adr                                              0.172185
# required_car_parking_spaces                      0.082626
# total_of_special_requests                        1.000000

# %%
# Plotting the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# ##### Categorical Data Analysis

# %%
# Perform one-hot encoding using pandas
df_encoded = pd.get_dummies(df, columns=cat_cols)
df_encoded
# Out:
#         is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0                 0        342               2015               July
# 1                 0        737               2015               July
# 2                 0          7               2015               July
# 3                 0         13               2015               July
# 4                 0         14               2015               July
# ...             ...        ...                ...                ...
# 119385            0         23               2017             August
# 119386            0        102               2017             August
# 119387            0         34               2017             August
# 119388            0        109               2017             August
# 119389            0        205               2017             August
#
#         arrival_date_week_number  arrival_date_day_of_month  \
# 0                             27                          1
# 1                             27                          1
# 2                             27                          1
# 3                             27                          1
# 4                             27                          1
# ...                          ...                        ...
# 119385                        35                         30
# 119386                        35                         31
# 119387                        35                         31
# 119388                        35                         31
# 119389                        35                         29
#
#         stays_in_weekend_nights  stays_in_week_nights  adults  children  ...  \
# 0                             0                     0     2.0       0.0  ...
# 1                             0                     0     2.0       0.0  ...
# 2                             0                     1     1.0       0.0  ...
# 3                             0                     1     1.0       0.0  ...
# 4                             0                     2     2.0       0.0  ...
# ...                         ...                   ...     ...       ...  ...
# 119385                        2                     5     2.0       0.0  ...
# 119386                        2                     5     3.0       0.0  ...
# 119387                        2                     5     2.0       0.0  ...
# 119388                        2                     5     2.0       0.0  ...
# 119389                        2                     7     2.0       0.0  ...
#
#         agent_527.0 agent_531.0  agent_535.0  customer_type_Contract  \
# 0             False       False        False                   False
# 1             False       False        False                   False
# 2             False       False        False                   False
# 3             False       False        False                   False
# 4             False       False        False                   False
# ...             ...         ...          ...                     ...
# 119385        False       False        False                   False
# 119386        False       False        False                   False
# 119387        False       False        False                   False
# 119388        False       False        False                   False
# 119389        False       False        False                   False
#
#         customer_type_Group  customer_type_Transient  \
# 0                     False                     True
# 1                     False                     True
# 2                     False                     True
# 3                     False                     True
# 4                     False                     True
# ...                     ...                      ...
# 119385                False                     True
# 119386                False                     True
# 119387                False                     True
# 119388                False                     True
# 119389                False                     True
#
#         customer_type_Transient-Party  reservation_status_Canceled  \
# 0                               False                        False
# 1                               False                        False
# 2                               False                        False
# 3                               False                        False
# 4                               False                        False
# ...                               ...                          ...
# 119385                          False                        False
# 119386                          False                        False
# 119387                          False                        False
# 119388                          False                        False
# 119389                          False                        False
#
#         reservation_status_Check-Out reservation_status_No-Show
# 0                               True                      False
# 1                               True                      False
# 2                               True                      False
# 3                               True                      False
# 4                               True                      False
# ...                              ...                        ...
# 119385                          True                      False
# 119386                          True                      False
# 119387                          True                      False
# 119388                          True                      False
# 119389                          True                      False
#
# [119390 rows x 579 columns]

# %%
hotel_counts = df['hotel'].value_counts()
hotel_counts
# Out:
# hotel
# City Hotel      79330
# Resort Hotel    40060
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 6))
hotel_counts.plot(kind='bar', color='teal')
plt.title('Count of Hotel Bookings')
plt.xlabel('Type of Hotel')
plt.ylabel('Number of Bookings')
plt.xticks(rotation=0)
plt.show()

# %%
country_counts = df['country'].value_counts()
country_counts
# Out:
# country
# PRT    49078
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
#        ...
# DJI        1
# BWA        1
# HND        1
# VGB        1
# NAM        1
# Name: count, Length: 177, dtype: int64

# %%
#Country distribution

plt.figure(figsize=(10, 8))
country_counts.head(10).plot(kind='pie', autopct='%1.1f%%')
plt.title('Country-wise Booking Distribution')
plt.ylabel('')
plt.show()

# %%
# Count the number of bookings for each market segment and distribution channel

marketSegment_counts = df['market_segment'].value_counts()
distChannel_counts = df['distribution_channel'].value_counts()

marketSegment_counts
# Out:
# market_segment
# Online TA        56479
# Offline TA/TO    24217
# Groups           19811
# Direct           12606
# Corporate         5295
# Complementary      743
# Aviation           237
# Undefined            2
# Name: count, dtype: int64

# %%
distChannel_counts
# Out:
# distribution_channel
# TA/TO        97870
# Direct       14645
# Corporate     6677
# GDS            193
# Undefined        5
# Name: count, dtype: int64

# %%
# Visualization of market distribution and distribution channel using bar plots
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
segment_counts.plot(kind='bar', color='teal')
plt.title('Market Segment Booking Counts')
plt.xlabel('Market Segment')
plt.ylabel('Number of Bookings')
plt.xticks(rotation=45)

plt.subplot(1, 2, 2)
channel_counts.plot(kind='bar', color='lightblue')
plt.title('Distribution Channel Booking Counts')
plt.xlabel('Distribution Channel')
plt.ylabel('Number of Bookings')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
# Count the number of bookings for each room type and deposit type
reserved_counts = df['reserved_room_type'].value_counts()
assigned_counts = df['assigned_room_type'].value_counts()
deposit_counts = df['deposit_type'].value_counts()

print(reserved_counts)
print(assigned_counts)
print(deposit_counts)
# Out:
# reserved_room_type
# A    85995
# D    19200
# E     6535
# F     2897
# G     2094
# B     1118
# C      932
# H      601
# P       12
# L        6
# Name: count, dtype: int64
# assigned_room_type
# A    74054
# D    25322
# E     7805
# F     3751
# G     2553
# C     2375
# B     2163
# H      712
# I      363
# K      279
# P       12
# L        1
# Name: count, dtype: int64
# deposit_type
# No Deposit    104652
# Non Refund     14576
# Refundable       162
# Name: count, dtype: int64

# %%
# Visualizing the bookings using bar plots
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
reserved_counts.plot(kind='bar', color='teal')
plt.title('Reserved Room Type Booking Counts')
plt.xlabel('Room Type')
plt.ylabel('Number of Bookings')
plt.xticks(rotation=0)

plt.subplot(2, 2, 2)
assigned_counts.plot(kind='bar', color='lightblue')
plt.title('Assigned Room Type Booking Counts')
plt.xlabel('Room Type')
plt.ylabel('Number of Bookings')
plt.xticks(rotation=0)

plt.subplot(2, 2, 3)
deposit_counts.plot(kind='bar', color='lightgreen')
plt.title('Deposit Type Booking Counts')
plt.xlabel('Deposit Type')
plt.ylabel('Number of Bookings')
plt.xticks(rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Time Series Analysis

# %%
year_counts = df['arrival_date_year'].value_counts().sort_index()
year_counts
# Out:
# arrival_date_year
# 2015    21996
# 2016    56707
# 2017    40687
# Name: count, dtype: int64

# %%
# Visualizing the distribution using a line plot

plt.figure(figsize=(10, 6))
year_counts.plot(kind='line', marker='o', color='red')
plt.title('Year-wise Booking Counts')
plt.xlabel('Year')
plt.ylabel('Number of Bookings')
plt.xticks(year_counts.index)
plt.grid(True)
plt.show()

# %%
# Count of the number of bookings for each month
month_counts = df['arrival_date_month'].value_counts().sort_index()
month_counts
# Out:
# arrival_date_month
# April        11089
# August       13877
# December      6780
# February      8068
# January       5929
# July         12661
# June         10939
# March         9794
# May          11791
# November      6794
# October      11160
# September    10508
# Name: count, dtype: int64

# %%
# Visualizing the distribution using a bar plot
plt.figure(figsize=(10, 6))
month_counts.plot(kind='bar', color='teal')
plt.title('Month-wise Booking Counts')
plt.xlabel('Month')
plt.ylabel('Number of Bookings')
plt.xticks(rotation=90)
plt.show()

# %%
# Count of the number of bookings for each week number
week_counts = df['arrival_date_week_number'].value_counts().sort_index()
week_counts
# Out:
# arrival_date_week_number
# 1     1047
# 2     1218
# 3     1319
# 4     1487
# 5     1387
# 6     1508
# 7     2109
# 8     2216
# 9     2117
# 10    2149
# 11    2070
# 12    2083
# 13    2416
# 14    2264
# 15    2689
# 16    2405
# 17    2805
# 18    2926
# 19    2402
# 20    2785
# 21    2854
# 22    2546
# 23    2621
# 24    2498
# 25    2663
# 26    2391
# 27    2664
# 28    2853
# 29    2763
# 30    3087
# 31    2741
# 32    3045
# 33    3580
# 34    3040
# 35    2593
# 36    2167
# 37    2229
# 38    2661
# 39    2581
# 40    2397
# 41    2699
# 42    2756
# 43    2352
# 44    2272
# 45    1941
# 46    1574
# 47    1685
# 48    1504
# 49    1782
# 50    1505
# 51     933
# 52    1195
# 53    1816
# Name: count, dtype: int64

# %%
# Visualizing the distribution using a line plot

plt.figure(figsize=(10, 6))
week_counts.plot(kind='line', marker='o', color='black')
plt.title('Week Number-wise Booking Counts')
plt.xlabel('Week Number')
plt.ylabel('Number of Bookings')
plt.grid(True)
plt.show()

# %%
# Count of the number of bookings for each day of the month
day_counts = df['arrival_date_day_of_month'].value_counts().sort_index()

# %%
# Visualize the distribution using a line plot
plt.figure(figsize=(10, 6))
day_counts.plot(kind='line', marker='.', color='blue')
plt.title('Day of Month-wise Booking Counts')
plt.xlabel('Day of Month')
plt.ylabel('Number of Bookings')
plt.grid(True)
plt.show()

# %%
# Combining year, month, and day columns to create a datetime column
df['arrival_date'] = pd.to_datetime(df[['arrival_date_year', 'arrival_date_month', 'arrival_date_day_of_month']].astype(str).agg('-'.join, axis=1), errors='coerce')

# Count of the number of bookings for each date
date_counts = df['arrival_date'].value_counts().sort_index()

# %%
# Visualize the distribution using a line plot
plt.figure(figsize=(12, 6))
date_counts.plot(kind='line', marker='.', color='teal')
plt.title('Date-wise Booking Counts')
plt.xlabel('Date')
plt.ylabel('Number of Bookings')
plt.grid(True)
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# Perform seasonal decomposition
decomposition = seasonal_decompose(date_counts, model='additive', period=30)

# Plot the decomposed components
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, figsize=(15, 12), sharex=True)

ax1.plot(decomposition.observed, label='Observed', color='tomato')
ax1.legend(loc='upper left')
ax1.set_ylabel('Observed')

ax2.plot(decomposition.trend, label='Trend', color='cyan')
ax2.legend(loc='upper left')
ax2.set_ylabel('Trend')

ax3.plot(decomposition.seasonal, label='Seasonal', color='magenta')
ax3.legend(loc='upper left')
ax3.set_ylabel('Seasonal')

ax4.plot(decomposition.resid, label='Residual', color='chocolate')
ax4.legend(loc='upper left')
ax4.set_ylabel('Residual')
ax4.set_xlabel('Date')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Feature Engineering

# %%
# Creating new features
df['total_stay_nights'] = df['stays_in_weekend_nights'] + df['stays_in_week_nights']
df['total_guests'] = df['adults'] + df['children'] + df['babies']
df['has_special_requests'] = df['total_of_special_requests'].apply(lambda x: 1 if x > 0 else 0)
df['has_booking_changes'] = df['booking_changes'].apply(lambda x: 1 if x > 0 else 0)

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...   adr  \
# 0                        0                     0     2.0  ...   0.0
# 1                        0                     0     2.0  ...   0.0
# 2                        0                     1     1.0  ...  75.0
# 3                        0                     1     1.0  ...  75.0
# 4                        0                     2     2.0  ...  98.0
#
#    required_car_parking_spaces total_of_special_requests reservation_status  \
# 0                            0                         0          Check-Out
# 1                            0                         0          Check-Out
# 2                            0                         0          Check-Out
# 3                            0                         0          Check-Out
# 4                            0                         1          Check-Out
#
#   reservation_status_date arrival_date  total_stay_nights  total_guests  \
# 0              2015-07-01   2015-07-01                  0           2.0
# 1              2015-07-01   2015-07-01                  0           2.0
# 2              2015-07-02   2015-07-01                  1           1.0
# 3              2015-07-02   2015-07-01                  1           1.0
# 4              2015-07-03   2015-07-01                  2           2.0
#
#    has_special_requests has_booking_changes
# 0                     0                   1
# 1                     0                   1
# 2                     0                   0
# 3                     0                   0
# 4                     1                   0
#
# [5 rows x 36 columns]

# %%
# Convert month names to numerical values
month_to_num = {
    'January': 1, 'February': 2, 'March': 3, 'April': 4, 'May': 5, 'June': 6,
    'July': 7, 'August': 8, 'September': 9, 'October': 10, 'November': 11, 'December': 12
}

df['arrival_date_month_num'] = df['arrival_date_month'].map(month_to_num)

# Create a single arrival date column by concatenating the components
df['arrival_date'] = pd.to_datetime(df['arrival_date_year'].astype(str) + '-' +
                                    df['arrival_date_month_num'].astype(str) + '-' +
                                    df['arrival_date_day_of_month'].astype(str))

# Extract season
def get_season(date):
    if date.month in [12, 1, 2]:
        return 'Winter'
    elif date.month in [3, 4, 5]:
        return 'Spring'
    elif date.month in [6, 7, 8]:
        return 'Summer'
    else:
        return 'Autumn'

df['season'] = df['arrival_date'].apply(get_season)

# Extract month name
df['month_name'] = df['arrival_date'].dt.month_name()

# Extract day of the week
df['day_of_week'] = df['arrival_date'].dt.day_name()

# %%
df[['arrival_date', 'season', 'month_name', 'day_of_week']]
# Out:
#        arrival_date  season month_name day_of_week
# 0        2015-07-01  Summer       July   Wednesday
# 1        2015-07-01  Summer       July   Wednesday
# 2        2015-07-01  Summer       July   Wednesday
# 3        2015-07-01  Summer       July   Wednesday
# 4        2015-07-01  Summer       July   Wednesday
# ...             ...     ...        ...         ...
# 119385   2017-08-30  Summer     August   Wednesday
# 119386   2017-08-31  Summer     August    Thursday
# 119387   2017-08-31  Summer     August    Thursday
# 119388   2017-08-31  Summer     August    Thursday
# 119389   2017-08-29  Summer     August     Tuesday
#
# [119390 rows x 4 columns]

# %%
# Extract additional features from reservation_status_date
df['reservation_year'] = df['reservation_status_date'].dt.year
df['reservation_month'] = df['reservation_status_date'].dt.month
df['reservation_day'] = df['reservation_status_date'].dt.day
df['reservation_day_of_week'] = df['reservation_status_date'].dt.dayofweek
df['reservation_week_of_year'] = df['reservation_status_date'].dt.isocalendar().week

# Display the updated DataFrame with new features
df[['reservation_status_date', 'reservation_year', 'reservation_month', 'reservation_day', 'reservation_day_of_week', 'reservation_week_of_year']]
# Out:
#        reservation_status_date  reservation_year  reservation_month  \
# 0                   2015-07-01              2015                  7
# 1                   2015-07-01              2015                  7
# 2                   2015-07-02              2015                  7
# 3                   2015-07-02              2015                  7
# 4                   2015-07-03              2015                  7
# ...                        ...               ...                ...
# 119385              2017-09-06              2017                  9
# 119386              2017-09-07              2017                  9
# 119387              2017-09-07              2017                  9
# 119388              2017-09-07              2017                  9
# 119389              2017-09-07              2017                  9
#
#         reservation_day  reservation_day_of_week  reservation_week_of_year
# 0                     1                        2                        27
# 1                     1                        2                        27
# 2                     2                        3                        27
# 3                     2                        3                        27
# 4                     3                        4                        27
# ...                 ...                      ...                       ...
# 119385                6                        2                        36
# 119386                7                        3                        36
# 119387                7                        3                        36
# 119388                7                        3                        36
# 119389                7                        3                        36
#
# [119390 rows x 6 columns]
